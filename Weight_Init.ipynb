# %% [markdown]
# <a href="https://colab.research.google.com/github/joynaomi81/Neural-Network-BootCamp/blob/main/Weight_Init.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn

# %%
layer = nn.Linear(4,4)

# %%
layer.weight.data
# Out:
# tensor([[-0.3526,  0.4265,  0.0853,  0.3292],
#         [ 0.0844, -0.4656, -0.0570, -0.4345],
#         [ 0.3537,  0.4902, -0.4738, -0.3716],
#         [ 0.0989, -0.3507, -0.3110,  0.3270]])

# %%
nn.init.uniform_(layer.weight,a=0,b=4)
# Out:
# Parameter containing:
# tensor([[2.5815, 3.5870, 3.3350, 3.5991],
#         [2.1459, 3.2907, 3.0146, 0.6631],
#         [1.9408, 3.7482, 0.0322, 3.2435],
#         [0.8185, 0.2409, 2.2694, 1.3897]], requires_grad=True)
